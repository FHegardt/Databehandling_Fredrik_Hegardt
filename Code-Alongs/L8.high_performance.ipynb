# %% [markdown]
# # High Performance
#
# mask = (x > 0.5) % (y < 0.5)
#
# ex:
# df = df[df[mask]]
# intermediate variables in memory
#
# ```python
# tmp1 (x > 0.5)
# tmp2 (y < 0.5)
# mask = tmp1 & tmp2
# ```
#
# Can use pd.eval("") -> performs elementwise directly using numexpr
#
# Good for compound expressions

# %%
import pandas as pd
import numpy as np

nrows, ncols = 1000000, 100
df1, df2, df3, df4 = [pd.DataFrame(np.random.randn(nrows,ncols)) for _ in range(4)]
df1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.430286  0.368033 -0.405037 -0.081377  1.203113 -0.963116  0.855610
# 1 -1.142929  0.154876 -0.435105 -0.780848 -0.030583  1.356635 -0.749856
# 2  0.443519  1.054843  0.283840  0.444484  0.255824  0.536550 -0.175455
# 3  2.545863  1.042790  1.087288  0.337961  0.361818  0.037705  0.236604
# 4  0.560399 -0.541371  0.699892  0.263667 -1.507937  0.469659  1.876406
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.090909  1.134815  0.192952  ...  1.400864  0.097015 -1.245528 -0.714713
# 1 -0.805077  2.106134  0.082590  ...  0.369797  0.816506 -1.452992  1.881600
# 2 -0.109455 -0.575948 -1.120123  ... -0.219025  3.321252  0.368421 -1.123599
# 3  1.680111 -1.004373  0.116887  ... -2.240301  0.106368  1.437631  1.100896
# 4 -0.587879  0.375981  0.576292  ... -0.769171  0.799461 -0.333139  0.300101
#
#          94        95        96        97        98        99
# 0  0.051876  3.077737 -1.302702 -0.799351 -0.830002  0.558278
# 1 -0.071023 -0.255898  0.626518  0.391179  0.930270 -0.181975
# 2 -0.551595 -1.959348 -1.797399  0.758465 -1.291171  1.720917
# 3 -1.369257 -1.111779  0.338750 -0.423102  0.460907  2.017007
# 4  1.004530 -0.248670 -0.100842  0.219072  0.280177 -0.665320
#
# [5 rows x 100 columns]

# %%
# %timeit df1 + df2 +df3 +df4
# %timeit pd.eval("df1 + df2 +df3 +df4")
# Out:
# 1.62 s ± 603 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 334 ms ± 11.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
plain = df1 +df2+df3+df4
sum_eval = pd.eval("df1 + df2 +df3 +df4")

sum_eval.equals(plain)
# Out:
# True

# %%
#df.eval()
rolls = pd.DataFrame(np.random.randint(1,6, (6,3)), columns = ["Die1", "Die2", "Die3"])
rolls.eval("Sum = Die1 + Die2 + Die3", inplace = True)
rolls
# Out:
#    Die1  Die2  Die3  Sum
# 0     5     4     2   11
# 1     1     2     3    6
# 2     5     1     5   11
# 3     4     5     2   11
# 4     3     2     5   10
# 5     2     5     5   12

# %%
# use variables
high = 11 
rolls.eval("Winner = Sum > @high", inplace = True)
rolls
# Out:
#    Die1  Die2  Die3  Sum  Winner
# 0     5     4     2   11   False
# 1     1     2     3    6   False
# 2     5     1     5   11   False
# 3     4     5     2   11   False
# 4     3     2     5   10   False
# 5     2     5     5   12    True

# %%
#traditional way
rolls[rolls["Sum"]<= high]
# Out:
#    Die1  Die2  Die3  Sum  Winner
# 0     5     4     2   11   False
# 1     1     2     3    6   False
# 2     5     1     5   11   False
# 3     4     5     2   11   False
# 4     3     2     5   10   False

# %% [markdown]
# # Query

# %%
rolls.query("Sum <= @high")
# Out:
#    Die1  Die2  Die3  Sum  Winner
# 0     5     4     2   11   False
# 1     1     2     3    6   False
# 2     5     1     5   11   False
# 3     4     5     2   11   False
# 4     3     2     5   10   False
